# %%
import torch
import torch.utils.data as data
from torchvision import transforms
import torchvision.transforms.functional as tans_f
import numpy as np
import pandas as pd
import librosa
import os
from PIL import Image
import random
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.image as mpimg
import librosa.display
import IPython.display as ipd

# %%
path = '/home/linhui.dai/pytorch_spectrogram/data/ravdess/Actor_01/03-01-01-01-01-01-01.wav'
ipd.Audio(path)

# %%
def scale_minmax(X, min=0.0, max=1.0):
    X_std = (X - X.min()) / (X.max() - X.min())
    X_scaled = X_std * (max - min) + min
    return X_scaled


y1, sr1 = librosa.load(path, duration=2.97)
plt.figure(figsize=(14, 5))
librosa.display.waveplot(y1, sr=sr1)

# %%
img = librosa.feature.melspectrogram(y=y1, n_mels=128, hop_length=512)
img = np.log(img + 1e-9)
assert ps.shape == (128, 128)
img = scale_minmax(ps, 0, 255).astype(np.uint8)
img = np.flip(img, axis=0)
img = 255-img 
imgplot = plt.imshow(img, cmap='Greys')
plt.colorbar()

# %%
from nlpaug.util.audio.loader import AudioLoader
from nlpaug.util.audio.visualizer import AudioVisualizer
import nlpaug.augmenter.spectrogram as nas
import nlpaug.flow as naf

# %%
aug_img = aug.substitute(img)
# aug_data = aug.substitute(data)
imgplot = plt.imshow(aug_img, cmap='Greys')
plt.colorbar()

# %%
aug = nas.LoudnessAug(zone=(0.1, 0.5))
aug_img = aug.substitute(img)
# aug_data = aug.substitute(data)
imgplot = plt.imshow(aug_img, cmap='Greys')
plt.colorbar()
